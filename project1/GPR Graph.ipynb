# %%
import matplotlib.pyplot as plt
import pandas as pd

gpr_csv = "gpr_clean.csv"

gpr_df = pd.read_csv(gpr_csv)


gpr_df.head()
# Out:
#                             DATE  GPRD
# 0  1970-01-01 00:00:00.020100101   148
# 1  1970-01-01 00:00:00.020100102   133
# 2  1970-01-01 00:00:00.020100103   173
# 3  1970-01-01 00:00:00.020100104   178
# 4  1970-01-01 00:00:00.020100105   221

# %%
gpr_df.plot(kind='line',x='DATE',y='GPRD')

plt.show()
