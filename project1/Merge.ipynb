# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

gpr_csv = "gpr_clean.csv"
crude_csv = "crude_oil_api.csv"

gpr_df = pd.read_csv(gpr_csv)
crude_df = pd.read_csv(crude_csv)



#gpr_df['Date'] = pd.to_datetime(gpr_df['Date'])

crude_df['Date'] = pd.to_datetime(crude_df['Date'])

#crude_df

gpr_df


# type(crude_df['Date'][0])

# gpr_merge_df = pd.merge(gpr_df, crude_df, on = 'Date', how = 'inner')

# gpr_merge_df
# Out:
#           Date  GPRD
# 0       1/1/10   148
# 1       1/2/10   133
# 2       1/3/10   173
# 3       1/4/10   178
# 4       1/5/10   221
# ...        ...   ...
# 3598   11/8/19   121
# 3599   11/9/19   171
# 3600  11/10/19    27
# 3601  11/11/19    73
# 3602  11/12/19   208
#
# [3603 rows x 2 columns]

# %%
#plt.figure(figsize=(20,10))

crude_df.plot('Date','Oil Price',figsize=(20,10))


gpr_df.plot('Date','GPRD',figsize=(20,10))

# %%
gpr2_csv = "gpr_clean2.csv"
crude2_csv = "crude_oil_api2.csv"

gpr2_df = pd.read_csv(gpr_csv)
crude2_df = pd.read_csv(crude_csv)

# %%
crude2_df.plot('Date','Oil Price')


gpr2_df.plot.bar('Date','GPRD',figsize=(15,8))
